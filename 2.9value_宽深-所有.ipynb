# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

# %%
from sklearn.metrics import classification_report

# %%
import pandas as pd
df=pd.read_csv("res.csv",encoding="utf-8")

df=df.dropna(axis=0)

# %%
df.shape
# Out:
# (8000, 308)

# %%
dfnew=pd.read_csv("source_y.csv",encoding="utf-8")

df=pd.concat([df,dfnew],axis=1)

df["happiness"].value_counts()

df["happiness"]=df["happiness"].map({1:0,2:1,3:2,4:3,5:4})
df=pd.concat([df[df["happiness"]==3].sample(frac=0.3),df[df["happiness"]!=3]],axis=0)
label=df["happiness"]
df["newcol_1"]=1
df["newcol_2"]=0
del df["happiness"]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df, label, test_size=0.2, random_state=42)

# %%
col=[]
for i in df.columns:
    col.append(i.split("_")[0])

import numpy as np
l=[]
first=0
last=0
colname=[]
for ind,i in enumerate(col):
    last+=1
    if last==len(col):
         
         print (df[df.columns[first:last]])
         colname.append(df.columns[first:last][0][:-2])
         l.append(np.argmax(df[df.columns[first:last]].values,axis=1))
         break
    if col[last]!=col[last-1]:
         print (df[df.columns[first:last]])
         colname.append(df.columns[first:last][0][:-2])
#          print (np.argmax(df[df.columns[first:last]].values,axis=1).max())
         l.append(np.argmax(df[df.columns[first:last]].values,axis=1))
         first=last
         last=last+1
         
#          break
# Out:
#       Class_1  Class_2  Class_3  Class_4  Class_5  Class_6  Class_7  Class_8  \
# 5433        0        0        0        0        1        0        0        0
# 3518        0        0        0        0        1        0        0        0
# 2647        0        0        0        0        1        0        0        0
# 3303        0        0        1        0        0        0        0        0
# 7089        0        0        1        0        0        0        0        0
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 7987        0        0        0        1        0        0        0        0
# 7992        0        0        0        0        1        0        0        0
# 7995        0        0        0        0        1        0        0        0
# 7996        0        0        1        0        0        0        0        0
# 7998        0        0        0        0        0        1        0        0
#
#       Class_9  Class_10
# 5433        0         0
# 3518        0         0
# 2647        0         0
# 3303        0         0
# 7089        0         0
# ...       ...       ...
# 7987        0         0
# 7992        0         0
# 7995        0         0
# 7996        0         0
# 7998        0         0
#
# [4627 rows x 10 columns]
#       class_14_1  class_14_2  class_14_3  class_14_4  class_14_5  class_14_6  \
# 5433           0           0           0           1           0           0
# 3518           0           1           0           0           0           0
# 2647           0           0           0           0           1           0
# 3303           0           0           1           0           0           0
# 7089           0           0           1           0           0           0
# ...          ...         ...         ...         ...         ...         ...
# 7987           0           0           0           1           0           0
# 7992           0           1           0           0           0           0
# 7995           1           0           0           0           0           0
# 7996           1           0           0           0           0           0
# 7998           0           0           0           1           0           0
#
#       class_14_7  class_14_8  class_14_9  class_14_10  ...  class_10_after_1  \
# 5433           0           0           0            0  ...                 0
# 3518           0           0           0            0  ...                 0
# 2647           0           0           0            0  ...                 0
# 3303           0           0           0            0  ...                 0
# 7089           0           0           0            0  ...                 0
# ...          ...         ...         ...          ...  ...               ...
# 7987           0           0           0            0  ...                 0
# 7992           0           0           0            0  ...                 0
# 7995           0           0           0            0  ...                 0
# 7996           0           0           0            0  ...                 0
# 7998           0           0           0            0  ...                 0
#
#       class_10_after_2  class_10_after_3  class_10_after_4  class_10_after_5  \
# 5433                 0                 0                 0                 0
# 3518                 0                 0                 0                 0
# 2647                 0                 0                 0                 1
# 3303                 0                 0                 0                 1
# 7089                 0                 0                 0                 0
# ...                ...               ...               ...               ...
# 7987                 0                 0                 0                 1
# 7992                 0                 0                 0                 0
# 7995                 0                 0                 0                 0
# 7996                 0                 1                 0                 0
# 7998                 0                 0                 0                 0
#
#       class_10_after_6  class_10_after_7  class_10_after_8  class_10_after_9  \
# 5433                 1                 0                 0                 0
# 3518                 1                 0                 0                 0
# 2647                 0                 0                 0                 0
# 3303                 0                 0                 0                 0
# 7089                 1                 0                 0                 0
# ...                ...               ...               ...               ...
# 7987                 0                 0                 0                 0
# 7992                 1                 0                 0                 0
# 7995                 0                 0                 1                 0
# 7996                 0                 0                 0                 0
# 7998                 1                 0                 0                 0
#
#       class_10_after_10
# 5433                  0
# 3518                  0
# 2647                  0
# 3303                  0
# 7089                  0
# ...                 ...
# 7987                  0
# 7992                  0
# 7995                  0
# 7996                  0
# 7998                  0
#
# [4627 rows x 30 columns]
#       equity_1  equity_2  equity_3  equity_4  equity_5
# 5433         0         0         0         1         0
# 3518         0         1         0         0         0
# 2647         0         0         1         0         0
# 3303         0         1         0         0         0
# 7089         0         1         0         0         0
# ...        ...       ...       ...       ...       ...
# 7987         0         0         0         1         0
# 7992         0         0         0         1         0
# 7995         0         0         1         0         0
# 7996         0         0         0         1         0
# 7998         0         0         1         0         0
#
# [4627 rows x 5 columns]
#       public_service_cut_1  public_service_cut_2  public_service_cut_3  \
# 5433                     0                     0                     1
# 3518                     0                     1                     0
# 2647                     0                     0                     1
# 3303                     0                     0                     0
# 7089                     1                     0                     0
# ...                    ...                   ...                   ...
# 7987                     0                     0                     1
# 7992                     1                     0                     0
# 7995                     1                     0                     0
# 7996                     0                     0                     1
# 7998                     0                     1                     0
#
#       public_service_cut_4
# 5433                     0
# 3518                     0
# 2647                     0
# 3303                     1
# 7089                     0
# ...                    ...
# 7987                     0
# 7992                     0
# 7995                     0
# 7996                     0
# 7998                     0
#
# [4627 rows x 4 columns]
#       socialize_1  socialize_2  socialize_3  socialize_4  socialize_5
# 5433            0            0            0            1            0
# 3518            0            1            0            0            0
# 2647            0            0            1            0            0
# 3303            0            1            0            0            0
# 7089            0            0            1            0            0
# ...           ...          ...          ...          ...          ...
# 7987            0            0            1            0            0
# 7992            0            1            0            0            0
# 7995            0            0            0            1            0
# 7996            0            0            0            1            0
# 7998            0            0            1            0            0
#
# [4627 rows x 5 columns]
#       relax_1  relax_2  relax_3  relax_4  relax_5
# 5433        0        0        0        0        1
# 3518        0        0        1        0        0
# 2647        0        0        1        0        0
# 3303        0        0        1        0        0
# 7089        0        0        1        0        0
# ...       ...      ...      ...      ...      ...
# 7987        0        0        1        0        0
# 7992        0        0        0        0        1
# 7995        0        0        0        1        0
# 7996        0        0        0        1        0
# 7998        0        0        0        1        0
#
# [4627 rows x 5 columns]
#       learn_1  learn_2  learn_3  learn_4  learn_5
# 5433        0        1        0        0        0
# 3518        0        1        0        0        0
# 2647        0        0        1        0        0
# 3303        1        0        0        0        0
# 7089        0        0        0        1        0
# ...       ...      ...      ...      ...      ...
# 7987        1        0        0        0        0
# 7992        1        0        0        0        0
# 7995        0        0        0        1        0
# 7996        1        0        0        0        0
# 7998        0        0        0        1        0
#
# [4627 rows x 5 columns]
#       leisure_mean_cut_1  leisure_mean_cut_2  leisure_mean_cut_3  \
# 5433                   0                   0                   1
# 3518                   0                   1                   0
# 2647                   0                   0                   1
# 3303                   0                   0                   1
# 7089                   0                   0                   1
# ...                  ...                 ...                 ...
# 7987                   0                   0                   1
# 7992                   0                   0                   1
# 7995                   0                   0                   1
# 7996                   0                   0                   0
# 7998                   0                   0                   1
#
#       leisure_mean_cut_4
# 5433                   0
# 3518                   0
# 2647                   0
# 3303                   0
# 7089                   0
# ...                  ...
# 7987                   0
# 7992                   0
# 7995                   0
# 7996                   1
# 7998                   0
#
# [4627 rows x 4 columns]
#       media_mean_cut_1  media_mean_cut_2  media_mean_cut_3
# 5433                 0                 0                 1
# 3518                 0                 0                 1
# 2647                 0                 0                 1
# 3303                 0                 0                 1
# 7089                 1                 0                 0
# ...                ...               ...               ...
# 7987                 0                 1                 0
# 7992                 0                 1                 0
# 7995                 0                 0                 1
# 7996                 0                 1                 0
# 7998                 0                 0                 1
#
# [4627 rows x 3 columns]
#       depression_1  depression_2  depression_3  depression_4  depression_5
# 5433             0             0             0             1             0
# 3518             0             0             0             0             1
# 2647             0             0             0             1             0
# 3303             0             0             1             0             0
# 7089             0             0             0             1             0
# ...            ...           ...           ...           ...           ...
# 7987             0             0             1             0             0
# 7992             0             0             0             0             1
# 7995             0             0             1             0             0
# 7996             0             0             1             0             0
# 7998             0             0             0             1             0
#
# [4627 rows x 5 columns]
#       gender_0  gender_1
# 5433         0         1
# 3518         1         0
# 2647         0         1
# 3303         1         0
# 7089         0         1
# ...        ...       ...
# 7987         0         1
# 7992         1         0
# 7995         0         1
# 7996         1         0
# 7998         1         0
#
# [4627 rows x 2 columns]
#       age_group_1  age_group_2  age_group_3  age_group_4  age_group_5
# 5433            0            1            0            0            0
# 3518            0            1            0            0            0
# 2647            0            1            0            0            0
# 3303            0            1            0            0            0
# 7089            1            0            0            0            0
# ...           ...          ...          ...          ...          ...
# 7987            0            0            1            0            0
# 7992            0            0            1            0            0
# 7995            0            1            0            0            0
# 7996            0            0            0            0            1
# 7998            0            1            0            0            0
#
# [4627 rows x 5 columns]
#       edu_group_1  edu_group_2  edu_group_3  edu_group_4  edu_group_5
# 5433            0            0            1            0            0
# 3518            0            1            0            0            0
# 2647            1            0            0            0            0
# 3303            1            0            0            0            0
# 7089            0            0            1            0            0
# ...           ...          ...          ...          ...          ...
# 7987            1            0            0            0            0
# 7992            0            1            0            0            0
# 7995            0            1            0            0            0
# 7996            1            0            0            0            0
# 7998            0            0            0            1            0
#
# [4627 rows x 5 columns]
#       bmi_cut_0  bmi_cut_1  bmi_cut_2
# 5433          0          1          0
# 3518          0          1          0
# 2647          0          1          0
# 3303          0          1          0
# 7089          1          0          0
# ...         ...        ...        ...
# 7987          0          1          0
# 7992          0          1          0
# 7995          0          1          0
# 7996          0          1          0
# 7998          0          1          0
#
# [4627 rows x 3 columns]
#       edu_status_1.0  edu_status_2.0  edu_status_3.0  edu_status_4.0
# 5433               0               0               0               1
# 3518               0               0               0               1
# 2647               0               0               0               1
# 3303               0               0               0               1
# 7089               1               0               0               0
# ...              ...             ...             ...             ...
# 7987               0               1               0               0
# 7992               0               0               0               1
# 7995               0               0               1               0
# 7996               0               0               0               1
# 7998               0               0               0               1
#
# [4627 rows x 4 columns]
#       health_1  health_2  health_3  health_4  health_5  health_problem_1  \
# 5433         0         0         0         1         0                 0
# 3518         0         0         0         0         1                 0
# 2647         0         0         0         1         0                 0
# 3303         0         0         1         0         0                 0
# 7089         0         0         0         1         0                 0
# ...        ...       ...       ...       ...       ...               ...
# 7987         0         1         0         0         0                 0
# 7992         0         0         0         0         1                 0
# 7995         0         0         0         0         1                 0
# 7996         0         0         1         0         0                 0
# 7998         0         0         1         0         0                 0
#
#       health_problem_2  health_problem_3  health_problem_4  health_problem_5
# 5433                 0                 0                 1                 0
# 3518                 0                 0                 0                 1
# 2647                 0                 0                 1                 0
# 3303                 0                 1                 0                 0
# 7089                 0                 0                 1                 0
# ...                ...               ...               ...               ...
# 7987                 1                 0                 0                 0
# 7992                 0                 0                 0                 1
# 7995                 0                 0                 1                 0
# 7996                 0                 1                 0                 0
# 7998                 0                 0                 1                 0
#
# [4627 rows x 10 columns]
#       marital_1  marital_2  marital_3  marital_4  marital_5  marital_6  \
# 5433          0          0          1          0          0          0
# 3518          0          0          1          0          0          0
# 2647          0          0          0          0          0          1
# 3303          0          0          1          0          0          0
# 7089          1          0          0          0          0          0
# ...         ...        ...        ...        ...        ...        ...
# 7987          0          0          1          0          0          0
# 7992          0          0          1          0          0          0
# 7995          0          0          1          0          0          0
# 7996          0          0          0          0          0          0
# 7998          1          0          0          0          0          0
#
#       marital_7  marital_1st_-3.0  marital_1st_-2.0  marital_1st_-1.0  ...  \
# 5433          0                 0                 0                 0  ...
# 3518          0                 0                 0                 0  ...
# 2647          0                 0                 0                 0  ...
# 3303          0                 0                 0                 0  ...
# 7089          0                 0                 0                 0  ...
# ...         ...               ...               ...               ...  ...
# 7987          0                 0                 0                 0  ...
# 7992          0                 0                 0                 0  ...
# 7995          0                 0                 0                 0  ...
# 7996          1                 0                 0                 0  ...
# 7998          0                 0                 0                 0  ...
#
#       marital_1st_2006.0  marital_1st_2007.0  marital_1st_2008.0  \
# 5433                   0                   0                   0
# 3518                   0                   0                   0
# 2647                   0                   0                   0
# 3303                   0                   0                   0
# 7089                   0                   0                   0
# ...                  ...                 ...                 ...
# 7987                   0                   0                   0
# 7992                   0                   0                   0
# 7995                   1                   0                   0
# 7996                   0                   0                   0
# 7998                   0                   0                   0
#
#       marital_1st_2009.0  marital_1st_2010.0  marital_1st_2011.0  \
# 5433                   0                   0                   0
# 3518                   0                   0                   0
# 2647                   0                   0                   0
# 3303                   0                   0                   0
# 7089                   0                   0                   0
# ...                  ...                 ...                 ...
# 7987                   0                   0                   0
# 7992                   0                   0                   0
# 7995                   0                   0                   0
# 7996                   0                   0                   0
# 7998                   0                   0                   0
#
#       marital_1st_2012.0  marital_1st_2013.0  marital_1st_2014.0  \
# 5433                   0                   0                   0
# 3518                   0                   0                   0
# 2647                   0                   0                   0
# 3303                   0                   0                   0
# 7089                   0                   0                   0
# ...                  ...                 ...                 ...
# 7987                   0                   0                   0
# 7992                   0                   0                   0
# 7995                   0                   0                   0
# 7996                   0                   0                   0
# 7998                   0                   0                   0
#
#       marital_1st_2015.0
# 5433                   0
# 3518                   0
# 2647                   0
# 3303                   0
# 7089                   0
# ...                  ...
# 7987                   0
# 7992                   0
# 7995                   0
# 7996                   0
# 7998                   0
#
# [4627 rows x 89 columns]
#       political_1  political_2  political_3  political_4
# 5433            0            0            0            1
# 3518            1            0            0            0
# 2647            1            0            0            0
# 3303            1            0            0            0
# 7089            0            1            0            0
# ...           ...          ...          ...          ...
# 7987            1            0            0            0
# 7992            1            0            0            0
# 7995            1            0            0            0
# 7996            1            0            0            0
# 7998            1            0            0            0
#
# [4627 rows x 4 columns]
#       religion_0  religion_1  religion_freq_1  religion_freq_2  \
# 5433           0           1                1                0
# 3518           0           1                1                0
# 2647           0           1                1                0
# 3303           0           1                1                0
# 7089           0           1                1                0
# ...          ...         ...              ...              ...
# 7987           0           1                1                0
# 7992           0           1                1                0
# 7995           0           1                1                0
# 7996           0           1                1                0
# 7998           0           1                1                0
#
#       religion_freq_3  religion_freq_4  religion_freq_5  religion_freq_6  \
# 5433                0                0                0                0
# 3518                0                0                0                0
# 2647                0                0                0                0
# 3303                0                0                0                0
# 7089                0                0                0                0
# ...               ...              ...              ...              ...
# 7987                0                0                0                0
# 7992                0                0                0                0
# 7995                0                0                0                0
# 7996                0                0                0                0
# 7998                0                0                0                0
#
#       religion_freq_7  religion_freq_8  religion_freq_9
# 5433                0                0                0
# 3518                0                0                0
# 2647                0                0                0
# 3303                0                0                0
# 7089                0                0                0
# ...               ...              ...              ...
# 7987                0                0                0
# 7992                0                0                0
# 7995                0                0                0
# 7996                0                0                0
# 7998                0                0                0
#
# [4627 rows x 11 columns]
#       hukou_1  hukou_2  hukou_3  hukou_4  hukou_5  hukou_6  hukou_7  hukou_8  \
# 5433        1        0        0        0        0        0        0        0
# 3518        0        1        0        0        0        0        0        0
# 2647        0        0        0        1        0        0        0        0
# 3303        0        1        0        0        0        0        0        0
# 7089        1        0        0        0        0        0        0        0
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 7987        1        0        0        0        0        0        0        0
# 7992        1        0        0        0        0        0        0        0
# 7995        1        0        0        0        0        0        0        0
# 7996        1        0        0        0        0        0        0        0
# 7998        0        1        0        0        0        0        0        0
#
#       hukou_loc_1.0  hukou_loc_2.0  hukou_loc_3.0  hukou_loc_4.0
# 5433              0              1              0              0
# 3518              0              0              1              0
# 2647              1              0              0              0
# 3303              1              0              0              0
# 7089              1              0              0              0
# ...             ...            ...            ...            ...
# 7987              1              0              0              0
# 7992              1              0              0              0
# 7995              1              0              0              0
# 7996              1              0              0              0
# 7998              0              0              1              0
#
# [4627 rows x 12 columns]
#       nationality_1  nationality_2  nationality_3  nationality_4  \
# 5433              1              0              0              0
# 3518              1              0              0              0
# 2647              1              0              0              0
# 3303              1              0              0              0
# 7089              1              0              0              0
# ...             ...            ...            ...            ...
# 7987              1              0              0              0
# 7992              1              0              0              0
# 7995              1              0              0              0
# 7996              1              0              0              0
# 7998              1              0              0              0
#
#       nationality_5  nationality_6  nationality_7  nationality_8
# 5433              0              0              0              0
# 3518              0              0              0              0
# 2647              0              0              0              0
# 3303              0              0              0              0
# 7089              0              0              0              0
# ...             ...            ...            ...            ...
# 7987              0              0              0              0
# 7992              0              0              0              0
# 7995              0              0              0              0
# 7996              0              0              0              0
# 7998              0              0              0              0
#
# [4627 rows x 8 columns]
#       family_status_1  family_status_2  family_status_3  family_status_4  \
# 5433                0                0                1                0
# 3518                0                0                1                0
# 2647                0                0                1                0
# 3303                0                1                0                0
# 7089                0                1                0                0
# ...               ...              ...              ...              ...
# 7987                0                0                1                0
# 7992                0                1                0                0
# 7995                0                0                1                0
# 7996                0                1                0                0
# 7998                0                0                1                0
#
#       family_status_5
# 5433                0
# 3518                0
# 2647                0
# 3303                0
# 7089                0
# ...               ...
# 7987                0
# 7992                0
# 7995                0
# 7996                0
# 7998                0
#
# [4627 rows x 5 columns]
#       car_0  car_1
# 5433      0      1
# 3518      1      0
# 2647      0      1
# 3303      1      0
# 7089      1      0
# ...     ...    ...
# 7987      1      0
# 7992      0      1
# 7995      0      1
# 7996      1      0
# 7998      1      0
#
# [4627 rows x 2 columns]
#       house_cut_0.0  house_cut_1.0
# 5433              1              0
# 3518              1              0
# 2647              0              1
# 3303              1              0
# 7089              1              0
# ...             ...            ...
# 7987              1              0
# 7992              1              0
# 7995              0              0
# 7996              1              0
# 7998              0              0
#
# [4627 rows x 2 columns]
#       is_invest_0  is_invest_1
# 5433            0            1
# 3518            0            1
# 2647            0            1
# 3303            0            1
# 7089            0            1
# ...           ...          ...
# 7987            0            1
# 7992            0            1
# 7995            0            1
# 7996            0            1
# 7998            0            1
#
# [4627 rows x 2 columns]
#       insur_mean_1.0  insur_mean_1.25  insur_mean_1.5  insur_mean_1.75  \
# 5433               0                0               1                0
# 3518               0                0               1                0
# 2647               0                0               1                0
# 3303               0                0               1                0
# 7089               0                0               0                1
# ...              ...              ...             ...              ...
# 7987               0                0               1                0
# 7992               0                0               1                0
# 7995               0                0               1                0
# 7996               0                0               1                0
# 7998               0                0               1                0
#
#       insur_mean_2.0
# 5433               0
# 3518               0
# 2647               0
# 3303               0
# 7089               0
# ...              ...
# 7987               0
# 7992               0
# 7995               0
# 7996               0
# 7998               0
#
# [4627 rows x 5 columns]
#       family_income_cut_0  family_income_cut_1  family_income_cut_2  \
# 5433                    0                    0                    0
# 3518                    0                    0                    0
# 2647                    0                    0                    0
# 3303                    0                    0                    0
# 7089                    0                    1                    0
# ...                   ...                  ...                  ...
# 7987                    0                    0                    0
# 7992                    0                    0                    0
# 7995                    0                    0                    0
# 7996                    0                    0                    1
# 7998                    0                    0                    0
#
#       family_income_cut_3  family_income_cut_4  family_income_cut_5
# 5433                    0                    0                    1
# 3518                    0                    1                    0
# 2647                    0                    0                    1
# 3303                    0                    1                    0
# 7089                    0                    0                    0
# ...                   ...                  ...                  ...
# 7987                    0                    1                    0
# 7992                    0                    1                    0
# 7995                    0                    1                    0
# 7996                    0                    0                    0
# 7998                    0                    0                    1
#
# [4627 rows x 6 columns]
#       s_income_cut_0  s_income_cut_1  s_income_cut_2  s_income_cut_3  \
# 5433               0               0               0               1
# 3518               0               0               0               0
# 2647               0               0               0               0
# 3303               0               0               0               0
# 7089               0               0               0               0
# ...              ...             ...             ...             ...
# 7987               0               0               0               0
# 7992               0               0               0               0
# 7995               0               0               0               1
# 7996               0               0               0               0
# 7998               0               0               0               0
#
#       s_income_cut_4  s_income_cut_5
# 5433               0               0
# 3518               1               0
# 2647               1               0
# 3303               1               0
# 7089               1               0
# ...              ...             ...
# 7987               1               0
# 7992               1               0
# 7995               0               0
# 7996               1               0
# 7998               1               0
#
# [4627 rows x 6 columns]
#       income_cut_0  income_cut_1  income_cut_2  income_cut_3  income_cut_4  \
# 5433             0             0             0             0             0
# 3518             0             0             0             0             1
# 2647             0             0             0             0             0
# 3303             0             0             0             0             1
# 7089             1             0             0             0             0
# ...            ...           ...           ...           ...           ...
# 7987             0             0             0             0             1
# 7992             0             0             0             1             0
# 7995             0             0             0             0             1
# 7996             0             0             0             1             0
# 7998             0             0             0             0             0
#
#       income_cut_5
# 5433             1
# 3518             0
# 2647             1
# 3303             0
# 7089             0
# ...            ...
# 7987             0
# 7992             0
# 7995             0
# 7996             0
# 7998             1
#
# [4627 rows x 6 columns]
#       floor_area_average_cut_1.0  floor_area_average_cut_2.0  \
# 5433                           0                           0
# 3518                           0                           0
# 2647                           0                           0
# 3303                           0                           1
# 7089                           0                           0
# ...                          ...                         ...
# 7987                           0                           0
# 7992                           0                           0
# 7995                           0                           0
# 7996                           0                           0
# 7998                           0                           0
#
#       floor_area_average_cut_3.0  floor_area_average_cut_4.0  \
# 5433                           0                           0
# 3518                           0                           1
# 2647                           0                           1
# 3303                           0                           0
# 7089                           0                           1
# ...                          ...                         ...
# 7987                           0                           1
# 7992                           0                           0
# 7995                           0                           0
# 7996                           0                           0
# 7998                           0                           0
#
#       floor_area_average_cut_5.0
# 5433                           1
# 3518                           0
# 2647                           0
# 3303                           0
# 7089                           0
# ...                          ...
# 7987                           0
# 7992                           1
# 7995                           1
# 7996                           1
# 7998                           1
#
# [4627 rows x 5 columns]
#       child_cut_1  child_cut_2  child_cut_3  child_cut_4
# 5433            0            0            1            0
# 3518            0            1            0            0
# 2647            0            0            1            0
# 3303            0            1            0            0
# 7089            1            0            0            0
# ...           ...          ...          ...          ...
# 7987            0            0            1            0
# 7992            0            1            0            0
# 7995            0            1            0            0
# 7996            0            1            0            0
# 7998            1            0            0            0
#
# [4627 rows x 4 columns]
#       minor_child_cut_1  minor_child_cut_2  minor_child_cut_3  \
# 5433                  0                  0                  1
# 3518                  0                  1                  0
# 2647                  0                  0                  1
# 3303                  0                  1                  0
# 7089                  1                  0                  0
# ...                 ...                ...                ...
# 7987                  1                  0                  0
# 7992                  1                  0                  0
# 7995                  0                  1                  0
# 7996                  1                  0                  0
# 7998                  1                  0                  0
#
#       minor_child_cut_4
# 5433                  0
# 3518                  0
# 2647                  0
# 3303                  0
# 7089                  0
# ...                 ...
# 7987                  0
# 7992                  0
# 7995                  0
# 7996                  0
# 7998                  0
#
# [4627 rows x 4 columns]
#       f_edu_1  f_edu_2  f_edu_3  f_edu_4  f_edu_5
# 5433        0        0        1        0        0
# 3518        0        1        0        0        0
# 2647        1        0        0        0        0
# 3303        1        0        0        0        0
# 7089        0        0        1        0        0
# ...       ...      ...      ...      ...      ...
# 7987        1        0        0        0        0
# 7992        0        1        0        0        0
# 7995        0        1        0        0        0
# 7996        1        0        0        0        0
# 7998        0        0        0        1        0
#
# [4627 rows x 5 columns]
#       m_edu_1  m_edu_2  m_edu_3  m_edu_4  m_edu_5
# 5433        0        0        1        0        0
# 3518        0        1        0        0        0
# 2647        1        0        0        0        0
# 3303        1        0        0        0        0
# 7089        0        0        1        0        0
# ...       ...      ...      ...      ...      ...
# 7987        1        0        0        0        0
# 7992        0        1        0        0        0
# 7995        0        1        0        0        0
# 7996        1        0        0        0        0
# 7998        0        0        0        1        0
#
# [4627 rows x 5 columns]
#       f_political_1  f_political_2  f_political_3  f_political_4
# 5433              0              0              0              1
# 3518              1              0              0              0
# 2647              1              0              0              0
# 3303              1              0              0              0
# 7089              1              0              0              0
# ...             ...            ...            ...            ...
# 7987              1              0              0              0
# 7992              1              0              0              0
# 7995              1              0              0              0
# 7996              1              0              0              0
# 7998              1              0              0              0
#
# [4627 rows x 4 columns]
#       m_political_1  m_political_2  m_political_3  m_political_4
# 5433              1              0              0              0
# 3518              1              0              0              0
# 2647              0              0              0              1
# 3303              1              0              0              0
# 7089              1              0              0              0
# ...             ...            ...            ...            ...
# 7987              1              0              0              0
# 7992              1              0              0              0
# 7995              1              0              0              0
# 7996              1              0              0              0
# 7998              1              0              0              0
#
# [4627 rows x 4 columns]
#       s_work_status_cut_1  s_work_status_cut_2  s_work_type_1.0  \
# 5433                    0                    1                1
# 3518                    0                    1                1
# 2647                    0                    1                1
# 3303                    0                    1                1
# 7089                    0                    1                1
# ...                   ...                  ...              ...
# 7987                    0                    1                1
# 7992                    0                    1                1
# 7995                    0                    1                1
# 7996                    0                    1                1
# 7998                    0                    1                1
#
#       s_work_type_2.0  s_work_exper_1.0  s_work_exper_2.0  s_work_exper_3.0  \
# 5433                0                 1                 0                 0
# 3518                0                 1                 0                 0
# 2647                0                 1                 0                 0
# 3303                0                 0                 0                 0
# 7089                0                 1                 0                 0
# ...               ...               ...               ...               ...
# 7987                0                 0                 0                 1
# 7992                0                 1                 0                 0
# 7995                0                 0                 0                 0
# 7996                0                 1                 0                 0
# 7998                0                 1                 0                 0
#
#       s_work_exper_4.0  s_work_exper_5.0  s_work_exper_6.0  s_political_1.0  \
# 5433                 0                 0                 0                1
# 3518                 0                 0                 0                1
# 2647                 0                 0                 0                0
# 3303                 0                 1                 0                1
# 7089                 0                 0                 0                0
# ...                ...               ...               ...              ...
# 7987                 0                 0                 0                1
# 7992                 0                 0                 0                1
# 7995                 1                 0                 0                1
# 7996                 0                 0                 0                0
# 7998                 0                 0                 0                0
#
#       s_political_2.0  s_political_3.0  s_political_4.0
# 5433                0                0                0
# 3518                0                0                0
# 2647                0                0                0
# 3303                0                0                0
# 7089                0                0                0
# ...               ...              ...              ...
# 7987                0                0                0
# 7992                0                0                0
# 7995                0                0                0
# 7996                0                0                0
# 7998                0                0                0
#
# [4627 rows x 14 columns]
#       newcol_1  newcol_2
# 5433         1         0
# 3518         1         0
# 2647         1         0
# 3303         1         0
# 7089         1         0
# ...        ...       ...
# 7987         1         0
# 7992         1         0
# 7995         1         0
# 7996         1         0
# 7998         1         0
#
# [4627 rows x 2 columns]

# %%
colname
# Out:
# ['Class',
#  'class_14',
#  'equity',
#  'public_service_cut',
#  'socialize',
#  'relax',
#  'learn',
#  'leisure_mean_cut',
#  'media_mean_cut',
#  'depression',
#  'gender',
#  'age_group',
#  'edu_group',
#  'bmi_cut',
#  'edu_status_1',
#  'health',
#  'marital',
#  'political',
#  'religion',
#  'hukou',
#  'nationality',
#  'family_status',
#  'car',
#  'house_cut_0',
#  'is_invest',
#  'insur_mean_1',
#  'family_income_cut',
#  's_income_cut',
#  'income_cut',
#  'floor_area_average_cut_1',
#  'child_cut',
#  'minor_child_cut',
#  'f_edu',
#  'm_edu',
#  'f_political',
#  'm_political',
#  's_work_status_cut',
#  'newcol']

# %%
colname[14]='edu_status'
colname[23]='house_cut'
colname[25]='insur_mean'
colname[29]='floor_area_average_cut'

# %%
colname
# Out:
# ['Class',
#  'class_14',
#  'equity',
#  'public_service_cut',
#  'socialize',
#  'relax',
#  'learn',
#  'leisure_mean_cut',
#  'media_mean_cut',
#  'depression',
#  'gender',
#  'age_group',
#  'edu_group',
#  'bmi_cut',
#  'edu_status',
#  'health',
#  'marital',
#  'political',
#  'religion',
#  'hukou',
#  'nationality',
#  'family_status',
#  'car',
#  'house_cut',
#  'is_invest',
#  'insur_mean',
#  'family_income_cut',
#  's_income_cut',
#  'income_cut',
#  'floor_area_average_cut',
#  'child_cut',
#  'minor_child_cut',
#  'f_edu',
#  'm_edu',
#  'f_political',
#  'm_political',
#  's_work_status_cut',
#  'newcol']

# %%
import pandas as pd

dfemd=pd.DataFrame()

embed_num=[]
for ind,i in enumerate(l):
    dfemd[ind]=i
    embed_num.append(len(dfemd[ind].unique())+2)

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras import *
import numpy as np
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Dense, Input, Dropout, Bidirectional

from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import re
from tensorflow.keras.callbacks import Callback
import tensorflow
from tensorflow.keras.models import load_model
from sklearn import metrics
from sklearn.model_selection import KFold


def get_deep_wide_net():
    embedall=[]
    for ind,i in enumerate(dfemd.columns):
         embedall.append(Embedding(100, 128, input_length=1,
                      trainable=True))

    len(embedall)

    input1 = Input(shape=(X_train.shape[1], )) #模型的入口,设置输入的维度
    embedl=[]
    for i in range(len(embedall)):
        embedl.append(Input(shape=(1,)))

    l=[]
    for i in range(len(embedl)):
        l.append(embedall[i](embedl[i]))

    embedcat=Concatenate()(l)

    embedcat=Dense(128,activation="relu")(embedcat)

    floatdense=Dense(128)(input1)
    embedcatnew=Flatten()(embedcat)

    last=Concatenate()([embedcatnew,floatdense])
    output1=Dense(128)(last)
    output = Dense(5, activation='softmax')(output1)#softmax层

    model = Model(inputs=[input1]+embedl, outputs=output)
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])#定义损失函数，优化器，评分标准
    model.summary()
    return model
# Out:
# /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
from sklearn import metrics
recal_all=[]
pre_all=[]
f1_all=[]
acc_all=[]
f1_micro=[]

t_recal_all=[]
t_pre_all=[]
t_f1_all=[]
t_acc_all=[]
t_f1_micro=[]
k=5
kf = KFold(n_splits=k, shuffle=True)
#     tmppre=np.zeros(y.shape)
ind=0
for (train, test) in  kf.split(df.values):
        print ("fold",ind,"start")
        X_train=df.values[train]
        y_train=label.values[train]
        emd_train=dfemd.values[train]
        emd_test=dfemd.values[test]
        train_all=[]
        train_all.append(X_train)
        for ind in range(emd_train.shape[1]):
            train_all.append(np.expand_dims(emd_train[:,ind],axis=1))
            
       
        X_test=df.values[test]
        testall=[]
        testall.append(X_test)
        for ind in range(emd_test.shape[1]):
            testall.append(np.expand_dims(emd_test[:,ind],axis=1))
#         break
        y_test=label.values[test]
        X_train=X_train.reshape(X_train.shape[0],X_train.shape[1])
        X_test=X_test.reshape(X_test.shape[0],X_test.shape[1])
        
        callbacks = [EarlyStopping(monitor='val_acc', verbose=1, patience=1000),
             ModelCheckpoint("model_wide_class_{}.hdf5".format(ind), monitor='val_acc',
                             mode='max', verbose=0, save_best_only=True,save_weights_only=True)]
        model_new = get_deep_wide_net()

        model_new.fit(train_all, y_train, epochs=20, batch_size=16, validation_data=(testall, y_test) ,callbacks=callbacks)
        model_new.load_weights("model_wide_class_{}.hdf5".format(ind)) #加载最优模型
        ypre=np.argmax(model_new.predict(testall),axis=-1)
        tmpacc=accuracy_score(y_test,ypre)
        tmppre=precision_score(y_test,ypre,average="macro")
        tmprecal=recall_score(y_test,ypre,average="macro")
        tmpf1=f1_score(y_test,ypre,average="macro")
        tmpf1_mic=f1_score(y_test,ypre,average="micro")
        print ("fold_{} acc: {} precision: {} recall : {} ,mac f1: {} ,mic f1: {}".format(ind,tmpacc,tmppre,tmprecal,tmpf1,tmpf1_mic))
        print ("test reprot: ",classification_report(y_test,ypre,digits=4))
        recal_all.append(tmprecal)
        acc_all.append(tmpacc)
        f1_all.append(tmpf1)
        pre_all.append(tmppre)
        f1_micro.append(tmpf1_mic)
        ind+=1

        ypre=np.argmax(model_new.predict(train_all),axis=-1)
        tmpacc=accuracy_score(y_train,ypre)
        tmppre=precision_score(y_train,ypre,average="macro")
        tmprecal=recall_score(y_train,ypre,average="macro")
        tmpf1=f1_score(y_train,ypre,average="macro")
        tmpf1_mic=f1_score(y_train,ypre,average="micro")
        print ("fold_{} train_acc: {} train_precision: {} train_recall : {},mac f1: {} ,mic f1: {}".format(ind,tmpacc,tmppre,tmprecal,tmpf1,tmpf1_mic))
        print ("train reprot: ",classification_report(y_train,ypre,digits=4))
        t_recal_all.append(tmprecal)
        t_acc_all.append(tmpacc)
        t_f1_all.append(tmpf1)
        t_pre_all.append(tmppre)
        t_f1_micro.append(tmpf1_mic)
    
print ("max acc:{}".format(max(acc_all)))
print ("min acc:{}".format(min(acc_all)))
print ("mean acc:{}".format(sum(acc_all)/5))


print ("max precision:{}".format(max(pre_all)))
print ("min precision:{}".format(min(pre_all)))
print ("mean precision:{}".format(sum(pre_all)/5))

print ("max recall:{}".format(max(recal_all)))
print ("min recall:{}".format(min(recal_all)))
print ("mean recall:{}".format(sum(recal_all)/5))



print ("max mac f1:{}".format(max(f1_all)))
print ("min mac f1:{}".format(min(f1_all)))
print ("mean mac f1:{}".format(sum(f1_all)/5))

print ("max mic f1:{}".format(max(f1_micro)))
print ("min mic f1:{}".format(min(f1_micro)))
print ("mean mic f1:{}".format(sum(f1_micro)/5))


print ("train max acc:{}".format(max(t_acc_all)))
print ("train min acc:{}".format(min(t_acc_all)))
print ("train mean acc:{}".format(sum(t_acc_all)/5))



print ("train max precision:{}".format(max(t_pre_all)))
print ("train min precision:{}".format(min(t_pre_all)))
print ("train mean precision:{}".format(sum(t_pre_all)/5))


print ("train max recall:{}".format(max(t_recal_all)))
print ("train min recall:{}".format(min(t_recal_all)))
print ("train mean recall:{}".format(sum(t_recal_all)/5))


print ("train max mac f1:{}".format(max(t_f1_all)))
print ("train min mac f1:{}".format(min(t_f1_all)))
print ("train mean mac f1:{}".format(sum(t_f1_all)/5))


print ("train max mic f1:{}".format(max(t_f1_micro)))
print ("train min mic f1:{}".format(min(t_f1_micro)))
print ("train mean mic f1:{}".format(sum(t_f1_micro)/5))
# Out:
# fold 0 start
# WARNING:tensorflow:From /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/kongmiao/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_19 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_20 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_21 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_22 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_23 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_24 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_25 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_26 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_27 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_28 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_29 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_30 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_31 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_32 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_33 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_34 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_35 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_36 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_37 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_38 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_39 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 128)       12800       input_2[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 128)       12800       input_3[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 128)       12800       input_4[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 128)       12800       input_5[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 1, 128)       12800       input_6[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 1, 128)       12800       input_7[0][0]
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 1, 128)       12800       input_8[0][0]
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 1, 128)       12800       input_9[0][0]
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 1, 128)       12800       input_10[0][0]
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 1, 128)       12800       input_11[0][0]
# __________________________________________________________________________________________________
# embedding_10 (Embedding)        (None, 1, 128)       12800       input_12[0][0]
# __________________________________________________________________________________________________
# embedding_11 (Embedding)        (None, 1, 128)       12800       input_13[0][0]
# __________________________________________________________________________________________________
# embedding_12 (Embedding)        (None, 1, 128)       12800       input_14[0][0]
# __________________________________________________________________________________________________
# embedding_13 (Embedding)        (None, 1, 128)       12800       input_15[0][0]
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, 1, 128)       12800       input_16[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, 1, 128)       12800       input_17[0][0]
# __________________________________________________________________________________________________
# embedding_16 (Embedding)        (None, 1, 128)       12800       input_18[0][0]
# __________________________________________________________________________________________________
# embedding_17 (Embedding)        (None, 1, 128)       12800       input_19[0][0]
# __________________________________________________________________________________________________
# embedding_18 (Embedding)        (None, 1, 128)       12800       input_20[0][0]
# __________________________________________________________________________________________________
# embedding_19 (Embedding)        (None, 1, 128)       12800       input_21[0][0]
# __________________________________________________________________________________________________
# embedding_20 (Embedding)        (None, 1, 128)       12800       input_22[0][0]
# __________________________________________________________________________________________________
# embedding_21 (Embedding)        (None, 1, 128)       12800       input_23[0][0]
# __________________________________________________________________________________________________
# embedding_22 (Embedding)        (None, 1, 128)       12800       input_24[0][0]
# __________________________________________________________________________________________________
# embedding_23 (Embedding)        (None, 1, 128)       12800       input_25[0][0]
# __________________________________________________________________________________________________
# embedding_24 (Embedding)        (None, 1, 128)       12800       input_26[0][0]
# __________________________________________________________________________________________________
# embedding_25 (Embedding)        (None, 1, 128)       12800       input_27[0][0]
# __________________________________________________________________________________________________
# embedding_26 (Embedding)        (None, 1, 128)       12800       input_28[0][0]
# __________________________________________________________________________________________________
# embedding_27 (Embedding)        (None, 1, 128)       12800       input_29[0][0]
# __________________________________________________________________________________________________
# embedding_28 (Embedding)        (None, 1, 128)       12800       input_30[0][0]
# __________________________________________________________________________________________________
# embedding_29 (Embedding)        (None, 1, 128)       12800       input_31[0][0]
# __________________________________________________________________________________________________
# embedding_30 (Embedding)        (None, 1, 128)       12800       input_32[0][0]
# __________________________________________________________________________________________________
# embedding_31 (Embedding)        (None, 1, 128)       12800       input_33[0][0]
# __________________________________________________________________________________________________
# embedding_32 (Embedding)        (None, 1, 128)       12800       input_34[0][0]
# __________________________________________________________________________________________________
# embedding_33 (Embedding)        (None, 1, 128)       12800       input_35[0][0]
# __________________________________________________________________________________________________
# embedding_34 (Embedding)        (None, 1, 128)       12800       input_36[0][0]
# __________________________________________________________________________________________________
# embedding_35 (Embedding)        (None, 1, 128)       12800       input_37[0][0]
# __________________________________________________________________________________________________
# embedding_36 (Embedding)        (None, 1, 128)       12800       input_38[0][0]
# __________________________________________________________________________________________________
# embedding_37 (Embedding)        (None, 1, 128)       12800       input_39[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1, 4864)      0           embedding[0][0]
#                                                                  embedding_1[0][0]
#                                                                  embedding_2[0][0]
#                                                                  embedding_3[0][0]
#                                                                  embedding_4[0][0]
#                                                                  embedding_5[0][0]
#                                                                  embedding_6[0][0]
#                                                                  embedding_7[0][0]
#                                                                  embedding_8[0][0]
#                                                                  embedding_9[0][0]
#                                                                  embedding_10[0][0]
#                                                                  embedding_11[0][0]
#                                                                  embedding_12[0][0]
#                                                                  embedding_13[0][0]
#                                                                  embedding_14[0][0]
#                                                                  embedding_15[0][0]
#                                                                  embedding_16[0][0]
#                                                                  embedding_17[0][0]
#                                                                  embedding_18[0][0]
#                                                                  embedding_19[0][0]
#                                                                  embedding_20[0][0]
#                                                                  embedding_21[0][0]
#                                                                  embedding_22[0][0]
#                                                                  embedding_23[0][0]
#                                                                  embedding_24[0][0]
#                                                                  embedding_25[0][0]
#                                                                  embedding_26[0][0]
#                                                                  embedding_27[0][0]
#                                                                  embedding_28[0][0]
#                                                                  embedding_29[0][0]
#                                                                  embedding_30[0][0]
#                                                                  embedding_31[0][0]
#                                                                  embedding_32[0][0]
#                                                                  embedding_33[0][0]
#                                                                  embedding_34[0][0]
#                                                                  embedding_35[0][0]
#                                                                  embedding_36[0][0]
#                                                                  embedding_37[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 128)       622720      concatenate[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 310)]        0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          39808       input_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256)          0           flatten[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          32896       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 5)            645         dense_2[0][0]
# ==================================================================================================
# Total params: 1,182,469
# Trainable params: 1,182,469
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 3701 samples, validate on 926 samples
# Epoch 1/20
# 3701/3701 [==============================] - 8s 2ms/sample - loss: 1.2397 - acc: 0.4342 - val_loss: 1.1759 - val_acc: 0.4449
# Epoch 2/20
# 3701/3701 [==============================] - 3s 943us/sample - loss: 1.1319 - acc: 0.4861 - val_loss: 1.1544 - val_acc: 0.4730
# Epoch 3/20
# 3701/3701 [==============================] - 3s 892us/sample - loss: 1.0985 - acc: 0.5123 - val_loss: 1.1632 - val_acc: 0.4741
# Epoch 4/20
# 3701/3701 [==============================] - 3s 847us/sample - loss: 1.0675 - acc: 0.5261 - val_loss: 1.1697 - val_acc: 0.4838
# Epoch 5/20
# 3701/3701 [==============================] - 3s 815us/sample - loss: 1.0237 - acc: 0.5496 - val_loss: 1.2415 - val_acc: 0.4546
# Epoch 6/20
# 3701/3701 [==============================] - 3s 812us/sample - loss: 0.9739 - acc: 0.5655 - val_loss: 1.3184 - val_acc: 0.4449
# Epoch 7/20
# 3701/3701 [==============================] - 3s 822us/sample - loss: 0.8808 - acc: 0.6231 - val_loss: 1.3008 - val_acc: 0.4568
# Epoch 8/20
# 3701/3701 [==============================] - 3s 855us/sample - loss: 0.7700 - acc: 0.6639 - val_loss: 1.4999 - val_acc: 0.4330
# Epoch 9/20
# 3701/3701 [==============================] - 3s 888us/sample - loss: 0.6690 - acc: 0.7206 - val_loss: 1.7136 - val_acc: 0.4384
# Epoch 10/20
# 3701/3701 [==============================] - 3s 887us/sample - loss: 0.5428 - acc: 0.7703 - val_loss: 1.9602 - val_acc: 0.4309
# Epoch 11/20
# 3701/3701 [==============================] - 3s 887us/sample - loss: 0.4442 - acc: 0.8225 - val_loss: 2.2864 - val_acc: 0.4136
# Epoch 12/20
# 3701/3701 [==============================] - 3s 903us/sample - loss: 0.3892 - acc: 0.8382 - val_loss: 2.6603 - val_acc: 0.4168
# Epoch 13/20
# 3701/3701 [==============================] - 3s 845us/sample - loss: 0.3202 - acc: 0.8754 - val_loss: 3.0088 - val_acc: 0.4244
# Epoch 14/20
# 3701/3701 [==============================] - 3s 841us/sample - loss: 0.2521 - acc: 0.9011 - val_loss: 3.2882 - val_acc: 0.4006
# Epoch 15/20
# 3701/3701 [==============================] - 3s 811us/sample - loss: 0.2192 - acc: 0.9162 - val_loss: 3.6865 - val_acc: 0.4374
# Epoch 16/20
# 3701/3701 [==============================] - 3s 677us/sample - loss: 0.1862 - acc: 0.9330 - val_loss: 4.2388 - val_acc: 0.4255
# Epoch 17/20
# 3701/3701 [==============================] - 2s 658us/sample - loss: 0.1638 - acc: 0.9360 - val_loss: 4.2921 - val_acc: 0.3974
# Epoch 18/20
# 3701/3701 [==============================] - 3s 679us/sample - loss: 0.1576 - acc: 0.9446 - val_loss: 4.8301 - val_acc: 0.4212
# Epoch 19/20
# 3701/3701 [==============================] - 3s 689us/sample - loss: 0.1382 - acc: 0.9511 - val_loss: 5.2380 - val_acc: 0.4017
# Epoch 20/20
# 3701/3701 [==============================] - 3s 898us/sample - loss: 0.1767 - acc: 0.9400 - val_loss: 4.9746 - val_acc: 0.4276
# fold_37 acc: 0.4838012958963283 precision: 0.45079074017194126 recall : 0.43523020619342156 ,mac f1: 0.4377678255696832 ,mic f1: 0.4838012958963283
# test reprot:                precision    recall  f1-score   support
#
#            0     0.3500    0.3684    0.3590        19
#            1     0.4366    0.2672    0.3316       116
#            2     0.4563    0.4017    0.4273       234
#            3     0.4377    0.5017    0.4675       287
#            4     0.5733    0.6370    0.6035       270
#
#     accuracy                         0.4838       926
#    macro avg     0.4508    0.4352    0.4378       926
# weighted avg     0.4800    0.4838    0.4777       926
#
# fold_38 train_acc: 0.5725479600108079 train_precision: 0.6027031639970728 train_recall : 0.5353591733482604,mac f1: 0.5583458038106438 ,mic f1: 0.5725479600108079
# train reprot:                precision    recall  f1-score   support
#
#            0     0.6522    0.5294    0.5844        85
#            1     0.6558    0.3701    0.4732       381
#            2     0.5865    0.5101    0.5457       937
#            3     0.5122    0.5794    0.5438      1158
#            4     0.6068    0.6877    0.6447      1140
#
#     accuracy                         0.5725      3701
#    macro avg     0.6027    0.5354    0.5583      3701
# weighted avg     0.5782    0.5725    0.5690      3701
#
# fold 38 start
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_41 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_42 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_43 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_44 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_45 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_46 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_47 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_48 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_49 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_50 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_51 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_52 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_53 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_54 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_55 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_56 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_57 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_58 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_59 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_60 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_61 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_62 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_63 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_64 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_65 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_66 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_67 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_68 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_69 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_70 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_71 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_72 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_73 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_74 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_75 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_76 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_77 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_78 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_38 (Embedding)        (None, 1, 128)       12800       input_41[0][0]
# __________________________________________________________________________________________________
# embedding_39 (Embedding)        (None, 1, 128)       12800       input_42[0][0]
# __________________________________________________________________________________________________
# embedding_40 (Embedding)        (None, 1, 128)       12800       input_43[0][0]
# __________________________________________________________________________________________________
# embedding_41 (Embedding)        (None, 1, 128)       12800       input_44[0][0]
# __________________________________________________________________________________________________
# embedding_42 (Embedding)        (None, 1, 128)       12800       input_45[0][0]
# __________________________________________________________________________________________________
# embedding_43 (Embedding)        (None, 1, 128)       12800       input_46[0][0]
# __________________________________________________________________________________________________
# embedding_44 (Embedding)        (None, 1, 128)       12800       input_47[0][0]
# __________________________________________________________________________________________________
# embedding_45 (Embedding)        (None, 1, 128)       12800       input_48[0][0]
# __________________________________________________________________________________________________
# embedding_46 (Embedding)        (None, 1, 128)       12800       input_49[0][0]
# __________________________________________________________________________________________________
# embedding_47 (Embedding)        (None, 1, 128)       12800       input_50[0][0]
# __________________________________________________________________________________________________
# embedding_48 (Embedding)        (None, 1, 128)       12800       input_51[0][0]
# __________________________________________________________________________________________________
# embedding_49 (Embedding)        (None, 1, 128)       12800       input_52[0][0]
# __________________________________________________________________________________________________
# embedding_50 (Embedding)        (None, 1, 128)       12800       input_53[0][0]
# __________________________________________________________________________________________________
# embedding_51 (Embedding)        (None, 1, 128)       12800       input_54[0][0]
# __________________________________________________________________________________________________
# embedding_52 (Embedding)        (None, 1, 128)       12800       input_55[0][0]
# __________________________________________________________________________________________________
# embedding_53 (Embedding)        (None, 1, 128)       12800       input_56[0][0]
# __________________________________________________________________________________________________
# embedding_54 (Embedding)        (None, 1, 128)       12800       input_57[0][0]
# __________________________________________________________________________________________________
# embedding_55 (Embedding)        (None, 1, 128)       12800       input_58[0][0]
# __________________________________________________________________________________________________
# embedding_56 (Embedding)        (None, 1, 128)       12800       input_59[0][0]
# __________________________________________________________________________________________________
# embedding_57 (Embedding)        (None, 1, 128)       12800       input_60[0][0]
# __________________________________________________________________________________________________
# embedding_58 (Embedding)        (None, 1, 128)       12800       input_61[0][0]
# __________________________________________________________________________________________________
# embedding_59 (Embedding)        (None, 1, 128)       12800       input_62[0][0]
# __________________________________________________________________________________________________
# embedding_60 (Embedding)        (None, 1, 128)       12800       input_63[0][0]
# __________________________________________________________________________________________________
# embedding_61 (Embedding)        (None, 1, 128)       12800       input_64[0][0]
# __________________________________________________________________________________________________
# embedding_62 (Embedding)        (None, 1, 128)       12800       input_65[0][0]
# __________________________________________________________________________________________________
# embedding_63 (Embedding)        (None, 1, 128)       12800       input_66[0][0]
# __________________________________________________________________________________________________
# embedding_64 (Embedding)        (None, 1, 128)       12800       input_67[0][0]
# __________________________________________________________________________________________________
# embedding_65 (Embedding)        (None, 1, 128)       12800       input_68[0][0]
# __________________________________________________________________________________________________
# embedding_66 (Embedding)        (None, 1, 128)       12800       input_69[0][0]
# __________________________________________________________________________________________________
# embedding_67 (Embedding)        (None, 1, 128)       12800       input_70[0][0]
# __________________________________________________________________________________________________
# embedding_68 (Embedding)        (None, 1, 128)       12800       input_71[0][0]
# __________________________________________________________________________________________________
# embedding_69 (Embedding)        (None, 1, 128)       12800       input_72[0][0]
# __________________________________________________________________________________________________
# embedding_70 (Embedding)        (None, 1, 128)       12800       input_73[0][0]
# __________________________________________________________________________________________________
# embedding_71 (Embedding)        (None, 1, 128)       12800       input_74[0][0]
# __________________________________________________________________________________________________
# embedding_72 (Embedding)        (None, 1, 128)       12800       input_75[0][0]
# __________________________________________________________________________________________________
# embedding_73 (Embedding)        (None, 1, 128)       12800       input_76[0][0]
# __________________________________________________________________________________________________
# embedding_74 (Embedding)        (None, 1, 128)       12800       input_77[0][0]
# __________________________________________________________________________________________________
# embedding_75 (Embedding)        (None, 1, 128)       12800       input_78[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1, 4864)      0           embedding_38[0][0]
#                                                                  embedding_39[0][0]
#                                                                  embedding_40[0][0]
#                                                                  embedding_41[0][0]
#                                                                  embedding_42[0][0]
#                                                                  embedding_43[0][0]
#                                                                  embedding_44[0][0]
#                                                                  embedding_45[0][0]
#                                                                  embedding_46[0][0]
#                                                                  embedding_47[0][0]
#                                                                  embedding_48[0][0]
#                                                                  embedding_49[0][0]
#                                                                  embedding_50[0][0]
#                                                                  embedding_51[0][0]
#                                                                  embedding_52[0][0]
#                                                                  embedding_53[0][0]
#                                                                  embedding_54[0][0]
#                                                                  embedding_55[0][0]
#                                                                  embedding_56[0][0]
#                                                                  embedding_57[0][0]
#                                                                  embedding_58[0][0]
#                                                                  embedding_59[0][0]
#                                                                  embedding_60[0][0]
#                                                                  embedding_61[0][0]
#                                                                  embedding_62[0][0]
#                                                                  embedding_63[0][0]
#                                                                  embedding_64[0][0]
#                                                                  embedding_65[0][0]
#                                                                  embedding_66[0][0]
#                                                                  embedding_67[0][0]
#                                                                  embedding_68[0][0]
#                                                                  embedding_69[0][0]
#                                                                  embedding_70[0][0]
#                                                                  embedding_71[0][0]
#                                                                  embedding_72[0][0]
#                                                                  embedding_73[0][0]
#                                                                  embedding_74[0][0]
#                                                                  embedding_75[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 128)       622720      concatenate_2[0][0]
# __________________________________________________________________________________________________
# input_40 (InputLayer)           [(None, 310)]        0
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 128)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          39808       input_40[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256)          0           flatten_1[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          32896       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 5)            645         dense_6[0][0]
# ==================================================================================================
# Total params: 1,182,469
# Trainable params: 1,182,469
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 3701 samples, validate on 926 samples
# Epoch 1/20
# 3701/3701 [==============================] - 9s 2ms/sample - loss: 1.2417 - acc: 0.4391 - val_loss: 1.1370 - val_acc: 0.4687
# Epoch 2/20
# 3701/3701 [==============================] - 3s 845us/sample - loss: 1.1324 - acc: 0.4864 - val_loss: 1.1446 - val_acc: 0.4546
# Epoch 3/20
# 3701/3701 [==============================] - 3s 851us/sample - loss: 1.0932 - acc: 0.5072 - val_loss: 1.1544 - val_acc: 0.4719
# Epoch 4/20
# 3701/3701 [==============================] - 3s 871us/sample - loss: 1.0673 - acc: 0.5180 - val_loss: 1.1879 - val_acc: 0.4590
# Epoch 5/20
# 3701/3701 [==============================] - 3s 945us/sample - loss: 1.0236 - acc: 0.5523 - val_loss: 1.1820 - val_acc: 0.4773
# Epoch 6/20
# 3701/3701 [==============================] - 3s 882us/sample - loss: 0.9541 - acc: 0.5861 - val_loss: 1.2430 - val_acc: 0.4492
# Epoch 7/20
# 3701/3701 [==============================] - 4s 1ms/sample - loss: 0.8648 - acc: 0.6290 - val_loss: 1.3747 - val_acc: 0.4471
# Epoch 8/20
# 3701/3701 [==============================] - 4s 1ms/sample - loss: 0.7695 - acc: 0.6693 - val_loss: 1.5118 - val_acc: 0.4471
# Epoch 9/20
# 3701/3701 [==============================] - 4s 1ms/sample - loss: 0.6354 - acc: 0.7433 - val_loss: 1.6915 - val_acc: 0.4255
# Epoch 10/20
# ...
# __________________________________________________________________________________________________
# embedding_164 (Embedding)       (None, 1, 128)       12800       input_170[0][0]
# __________________________________________________________________________________________________
# embedding_165 (Embedding)       (None, 1, 128)       12800       input_171[0][0]
# __________________________________________________________________________________________________
# embedding_166 (Embedding)       (None, 1, 128)       12800       input_172[0][0]
# __________________________________________________________________________________________________
# embedding_167 (Embedding)       (None, 1, 128)       12800       input_173[0][0]
# __________________________________________________________________________________________________
# embedding_168 (Embedding)       (None, 1, 128)       12800       input_174[0][0]
# __________________________________________________________________________________________________
# embedding_169 (Embedding)       (None, 1, 128)       12800       input_175[0][0]
# __________________________________________________________________________________________________
# embedding_170 (Embedding)       (None, 1, 128)       12800       input_176[0][0]
# __________________________________________________________________________________________________
# embedding_171 (Embedding)       (None, 1, 128)       12800       input_177[0][0]
# __________________________________________________________________________________________________
# embedding_172 (Embedding)       (None, 1, 128)       12800       input_178[0][0]
# __________________________________________________________________________________________________
# embedding_173 (Embedding)       (None, 1, 128)       12800       input_179[0][0]
# __________________________________________________________________________________________________
# embedding_174 (Embedding)       (None, 1, 128)       12800       input_180[0][0]
# __________________________________________________________________________________________________
# embedding_175 (Embedding)       (None, 1, 128)       12800       input_181[0][0]
# __________________________________________________________________________________________________
# embedding_176 (Embedding)       (None, 1, 128)       12800       input_182[0][0]
# __________________________________________________________________________________________________
# embedding_177 (Embedding)       (None, 1, 128)       12800       input_183[0][0]
# __________________________________________________________________________________________________
# embedding_178 (Embedding)       (None, 1, 128)       12800       input_184[0][0]
# __________________________________________________________________________________________________
# embedding_179 (Embedding)       (None, 1, 128)       12800       input_185[0][0]
# __________________________________________________________________________________________________
# embedding_180 (Embedding)       (None, 1, 128)       12800       input_186[0][0]
# __________________________________________________________________________________________________
# embedding_181 (Embedding)       (None, 1, 128)       12800       input_187[0][0]
# __________________________________________________________________________________________________
# embedding_182 (Embedding)       (None, 1, 128)       12800       input_188[0][0]
# __________________________________________________________________________________________________
# embedding_183 (Embedding)       (None, 1, 128)       12800       input_189[0][0]
# __________________________________________________________________________________________________
# embedding_184 (Embedding)       (None, 1, 128)       12800       input_190[0][0]
# __________________________________________________________________________________________________
# embedding_185 (Embedding)       (None, 1, 128)       12800       input_191[0][0]
# __________________________________________________________________________________________________
# embedding_186 (Embedding)       (None, 1, 128)       12800       input_192[0][0]
# __________________________________________________________________________________________________
# embedding_187 (Embedding)       (None, 1, 128)       12800       input_193[0][0]
# __________________________________________________________________________________________________
# embedding_188 (Embedding)       (None, 1, 128)       12800       input_194[0][0]
# __________________________________________________________________________________________________
# embedding_189 (Embedding)       (None, 1, 128)       12800       input_195[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 1, 4864)      0           embedding_152[0][0]
#                                                                  embedding_153[0][0]
#                                                                  embedding_154[0][0]
#                                                                  embedding_155[0][0]
#                                                                  embedding_156[0][0]
#                                                                  embedding_157[0][0]
#                                                                  embedding_158[0][0]
#                                                                  embedding_159[0][0]
#                                                                  embedding_160[0][0]
#                                                                  embedding_161[0][0]
#                                                                  embedding_162[0][0]
#                                                                  embedding_163[0][0]
#                                                                  embedding_164[0][0]
#                                                                  embedding_165[0][0]
#                                                                  embedding_166[0][0]
#                                                                  embedding_167[0][0]
#                                                                  embedding_168[0][0]
#                                                                  embedding_169[0][0]
#                                                                  embedding_170[0][0]
#                                                                  embedding_171[0][0]
#                                                                  embedding_172[0][0]
#                                                                  embedding_173[0][0]
#                                                                  embedding_174[0][0]
#                                                                  embedding_175[0][0]
#                                                                  embedding_176[0][0]
#                                                                  embedding_177[0][0]
#                                                                  embedding_178[0][0]
#                                                                  embedding_179[0][0]
#                                                                  embedding_180[0][0]
#                                                                  embedding_181[0][0]
#                                                                  embedding_182[0][0]
#                                                                  embedding_183[0][0]
#                                                                  embedding_184[0][0]
#                                                                  embedding_185[0][0]
#                                                                  embedding_186[0][0]
#                                                                  embedding_187[0][0]
#                                                                  embedding_188[0][0]
#                                                                  embedding_189[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1, 128)       622720      concatenate_8[0][0]
# __________________________________________________________________________________________________
# input_157 (InputLayer)          [(None, 310)]        0
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 128)          0           dense_16[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 128)          39808       input_157[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 256)          0           flatten_4[0][0]
#                                                                  dense_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 128)          32896       concatenate_9[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 5)            645         dense_18[0][0]
# ==================================================================================================
# Total params: 1,182,469
# Trainable params: 1,182,469
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 3702 samples, validate on 925 samples
# Epoch 1/20
# 3702/3702 [==============================] - 15s 4ms/sample - loss: 1.2242 - acc: 0.4489 - val_loss: 1.1863 - val_acc: 0.4476
# Epoch 2/20
# 3702/3702 [==============================] - 2s 674us/sample - loss: 1.1233 - acc: 0.4916 - val_loss: 1.2394 - val_acc: 0.4605
# Epoch 3/20
# 3702/3702 [==============================] - 2s 671us/sample - loss: 1.0979 - acc: 0.5041 - val_loss: 1.1720 - val_acc: 0.4886
# Epoch 4/20
# 3702/3702 [==============================] - 2s 656us/sample - loss: 1.0709 - acc: 0.5122 - val_loss: 1.1841 - val_acc: 0.4659
# Epoch 5/20
# 3702/3702 [==============================] - 2s 665us/sample - loss: 1.0377 - acc: 0.5408 - val_loss: 1.2108 - val_acc: 0.4368
# Epoch 6/20
# 3702/3702 [==============================] - 3s 698us/sample - loss: 0.9852 - acc: 0.5654 - val_loss: 1.2094 - val_acc: 0.4778
# Epoch 7/20
# 3702/3702 [==============================] - 3s 730us/sample - loss: 0.9057 - acc: 0.6053 - val_loss: 1.2925 - val_acc: 0.4573
# Epoch 8/20
# 3702/3702 [==============================] - 2s 647us/sample - loss: 0.8085 - acc: 0.6599 - val_loss: 1.4089 - val_acc: 0.4162
# Epoch 9/20
# 3702/3702 [==============================] - 2s 652us/sample - loss: 0.6984 - acc: 0.7239 - val_loss: 1.6035 - val_acc: 0.4292
# Epoch 10/20
# 3702/3702 [==============================] - 2s 657us/sample - loss: 0.5766 - acc: 0.7682 - val_loss: 1.7509 - val_acc: 0.4270
# Epoch 11/20
# 3702/3702 [==============================] - 2s 644us/sample - loss: 0.4930 - acc: 0.8155 - val_loss: 1.9680 - val_acc: 0.4346
# Epoch 12/20
# 3702/3702 [==============================] - 2s 645us/sample - loss: 0.4020 - acc: 0.8414 - val_loss: 2.3157 - val_acc: 0.4022
# Epoch 13/20
# 3702/3702 [==============================] - 2s 648us/sample - loss: 0.3252 - acc: 0.8747 - val_loss: 2.5888 - val_acc: 0.4108
# Epoch 14/20
# 3702/3702 [==============================] - 2s 647us/sample - loss: 0.2643 - acc: 0.9022 - val_loss: 3.2262 - val_acc: 0.4054
# Epoch 15/20
# 3702/3702 [==============================] - 2s 648us/sample - loss: 0.2029 - acc: 0.9284 - val_loss: 3.2030 - val_acc: 0.3989
# Epoch 16/20
# 3702/3702 [==============================] - 2s 647us/sample - loss: 0.2104 - acc: 0.9214 - val_loss: 3.7179 - val_acc: 0.3805
# Epoch 17/20
# 3702/3702 [==============================] - 2s 646us/sample - loss: 0.2115 - acc: 0.9217 - val_loss: 3.8874 - val_acc: 0.4141
# Epoch 18/20
# 3702/3702 [==============================] - 2s 652us/sample - loss: 0.1597 - acc: 0.9433 - val_loss: 4.3782 - val_acc: 0.4000
# Epoch 19/20
# 3702/3702 [==============================] - 3s 679us/sample - loss: 0.0913 - acc: 0.9662 - val_loss: 4.8775 - val_acc: 0.4097
# Epoch 20/20
# 3702/3702 [==============================] - 2s 665us/sample - loss: 0.0943 - acc: 0.9687 - val_loss: 5.2360 - val_acc: 0.4259
# fold_37 acc: 0.48864864864864865 precision: 0.45586711852647505 recall : 0.438371910239116 ,mac f1: 0.4409137090895924 ,mic f1: 0.48864864864864865
# test reprot:                precision    recall  f1-score   support
#
#            0     0.4211    0.3077    0.3556        26
#            1     0.3708    0.3367    0.3529        98
#            2     0.4793    0.5022    0.4905       231
#            3     0.4695    0.3413    0.3953       293
#            4     0.5387    0.7040    0.6103       277
#
#     accuracy                         0.4886       925
#    macro avg     0.4559    0.4384    0.4409       925
# weighted avg     0.4808    0.4886    0.4778       925
#
# fold_38 train_acc: 0.5559157212317666 train_precision: 0.5682998765777425 train_recall : 0.5383830121602433,mac f1: 0.54533313354361 ,mic f1: 0.5559157212317666
# train reprot:                precision    recall  f1-score   support
#
#            0     0.6500    0.5000    0.5652        78
#            1     0.5349    0.4987    0.5162       399
#            2     0.5283    0.5468    0.5374       940
#            3     0.5499    0.3776    0.4478      1152
#            4     0.5784    0.7688    0.6601      1133
#
#     accuracy                         0.5559      3702
#    macro avg     0.5683    0.5384    0.5453      3702
# weighted avg     0.5536    0.5559    0.5454      3702
#
# max acc:0.48864864864864865
# min acc:0.4745945945945946
# mean acc:0.48173813554375106
# max precision:0.5059525054169061
# min precision:0.4444797733514734
# mean precision:0.4656668879151481
# max recall:0.438371910239116
# min recall:0.4016428189292999
# mean recall:0.4267506699177416
# max mac f1:0.44196853388147606
# min mac f1:0.40918120923660944
# mean mac f1:0.4341826485541695
# max mic f1:0.48864864864864865
# min mic f1:0.4745945945945946
# mean mic f1:0.48173813554375106
# train max acc:0.6171305052688463
# train min acc:0.51107509454349
# train mean acc:0.5614905282801339
# train max precision:0.6275449281317504
# train min precision:0.5379935440266548
# train mean precision:0.5791554882793762
# train max recall:0.585703954734916
# train min recall:0.44774452342554927
# train mean recall:0.5242864849935982
# train max mac f1:0.5988774771467379
# train min mac f1:0.46058055500054973
# train mean mac f1:0.5375101950221927
# train max mic f1:0.6171305052688463
# train min mic f1:0.51107509454349
# train mean mic f1:0.5614905282801339

# %%
import random

# %%
#model_new.load_weights("model_wide_class_{}.hdf5".format(ind))

# %%
from tqdm import tqdm
def get_important(col="gender",M=100,I=100):
    
    sumall=[]
    for num in tqdm(range(I)):
        num_fea=colname.index(col)+1
        for i in random.sample(list(range(len(train_all))),1):  # (1)随机采样一条样本xi
        #     print (i)
            xi=[]
            for j in range(len(train_all)):
                xi.append(train_all[j][i:i+1])
        tmp1=[]
        for i in range(M):
            for i in random.sample(list(range(len(train_all))),1): #(2)随机采样一条样本z
        #         print (i)
                z=[]
                for j in range(len(train_all)):
                    z.append(train_all[j][i:i+1])
            shutuf=random.sample(list(range(len(colname))),len(colname)) #(3)随机采样1到n排列 

            x_=[xi[0]]+list(np.array(xi[1:])[shutuf])#（4）
            z_=[z[0]]+list(np.array(z[1:])[shutuf])#(5)

            x_1=x_[:1+num_fea]+z_[1+num_fea:]
            x_2=x_[:num_fea]+z_[num_fea:] #(6)

        #     print (abs(np.mean(model_new.predict(x_1)-model_new.predict(x_2),axis=1)[0])) #(7)
            tmp1.append(abs(model_new.predict(x_1)-model_new.predict(x_2)))
        sumall.append(tmp1)
    return np.mean(np.array(sumall),axis=0)[0]

# %%
fea_import=[]
for col in colname:
    tmp=get_important(col,M=30,I=30)
    fea_import.append(tmp)
# Out:
# 100%|██████████| 30/30 [00:12<00:00,  2.38it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.52it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.62it/s]
# 100%|██████████| 30/30 [00:12<00:00,  2.45it/s]
# 100%|██████████| 30/30 [00:12<00:00,  2.49it/s]
# 100%|██████████| 30/30 [00:12<00:00,  2.48it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.56it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.57it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.66it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.74it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.76it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.76it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.97it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.71it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.63it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.73it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.66it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.69it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.02it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.02it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.75it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.60it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.55it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.57it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.65it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.53it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.58it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.67it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.72it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.68it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.87it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.98it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.71it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.79it/s]
# 100%|██████████| 30/30 [00:11<00:00,  2.56it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.80it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.86it/s]
# 100%|██████████| 30/30 [00:10<00:00,  2.82it/s]

# %%
dfnew=pd.DataFrame(np.squeeze(np.array(fea_import)))
dfnew.columns=[str(i)+"_重要度" for  i in [1,2,3,4,5]]

# %%
dfnew.index=colname

# %%
dfnew=dfnew[:-1]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

plt.figure(figsize=(10,10))
sns.heatmap(data=dfnew,linewidths=1,annot=True,cmap="GnBu",fmt=".5f")
plt.savefig("2.9宽深-value所有.png",dpi=300)

# %%
dfnew=dfnew.sort_values(by="3_重要度",ascending=False)
dfnew=dfnew[:10]
plt.figure(figsize=(10,10))
sns.heatmap(data=dfnew,linewidths=1,annot=True,cmap="GnBu",fmt=".5f")
plt.savefig("2.9宽深value_排序前10个所有另.png",dpi=300)

# %%
dfnew=dfnew.sort_values(by="3_重要度",ascending=False)
dfnew=dfnew[:10]
plt.figure(figsize=(10,10))
sns.heatmap(data=dfnew,linewidths=1,annot=True,cmap="GnBu",fmt=".5f")
plt.savefig("2.9宽深value_排序前10个所有另.pdf",dpi=300)

# %%
dfnew=dfnew.sort_values(by="3_重要度",ascending=False)
dfnew=dfnew[:5]
plt.figure(figsize=(10,10))
sns.heatmap(data=dfnew,linewidths=1,annot=True,cmap="GnBu",fmt=".5f")
plt.savefig("2.9宽深value_排序前5个所有另.png",dpi=300)

# %%
dfnew=dfnew.sort_values(by="3_重要度",ascending=False)
dfnew=dfnew[:5]
plt.figure(figsize=(10,10))
sns.heatmap(data=dfnew,linewidths=1,annot=True,cmap="GnBu",fmt=".5f")
plt.savefig("2.9宽深value_排序前5个所有另.pdf",dpi=300)
